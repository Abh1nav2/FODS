# %% [markdown]
# CB.EN.U4CSE20201 DS_LAB_EVAL
# SET 1

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import matplotlib as mpl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('classic') 
# %matplotlib inline

# %%
#1
df=pd.read_csv('/content/drive/MyDrive/Data Science/labeval_ds.csv')
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
#2
df.drop(columns=['Month of absence','Disciplinary failure','Day of the week'],inplace=True)
df
# Out:
#      ID  Seasons  Transportation expense  Distance from Residence to Work  \
# 0    11        1                     289                               36
# 1    36        1                     118                               13
# 2     3        1                     179                               51
# 3     7        1                     279                                5
# 4    11        1                     289                               36
# ..   ..      ...                     ...                              ...
# 735  11        1                     289                               36
# 736   1        1                     235                               11
# 737   4        1                     118                               14
# 738   8        2                     231                               35
# 739  35        3                     179                               45
#
#      Service time  Age  Work load Average/day   Hit target  Education  Son  \
# ...

# %%
#3
df.isna()
# Out:
#         ID  Seasons  Transportation expense  Distance from Residence to Work  \
# 0    False    False                   False                            False
# 1    False    False                   False                            False
# 2    False    False                   False                            False
# 3    False    False                   False                            False
# 4    False    False                   False                            False
# ..     ...      ...                     ...                              ...
# 735  False    False                   False                            False
# 736  False    False                   False                            False
# 737  False    False                   False                            False
# 738  False    False                   False                            False
# 739  False    False                   False                            False
#
# ...

# %%
#4
out=df.boxplot(column='Height',by='Seasons')
out
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
#5
print(df['Age'].corr(df['Absenteeism time in hours']))
# Out:
# 0.06575970132037091

# %%
#6
df.describe()
# Out:
#                ID     Seasons  Transportation expense  \
# count  740.000000  740.000000              740.000000
# mean    18.017568    2.544595              221.329730
# std     11.021247    1.111831               66.952223
# min      1.000000    1.000000              118.000000
# 25%      9.000000    2.000000              179.000000
# 50%     18.000000    3.000000              225.000000
# 75%     28.000000    4.000000              260.000000
# max     36.000000    4.000000              388.000000
#
#        Distance from Residence to Work  Service time         Age  \
# count                       740.000000    740.000000  740.000000
# mean                         29.631081     12.554054   36.450000
# std                          14.836788      4.384873    6.478772
# min                           5.000000      1.000000   27.000000
# 25%                          16.000000      9.000000   31.000000
# 50%                          26.000000     13.000000   37.000000
# ...

# %%
#7
df.head(3)
# Out:
#    ID  Seasons  Transportation expense  Distance from Residence to Work  \
# 0  11        1                     289                               36
# 1  36        1                     118                               13
# 2   3        1                     179                               51
#
#    Service time  Age  Work load Average/day   Hit target  Education  Son  \
# 0            13   33                 239.554          97          1    2
# 1            18   50                 239.554          97          1    1
# 2            18   38                 239.554          97          1    0
#
#    Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 0               1              0    1      90     172               30
# 1               1              0    0      98     178               31
# 2               1              0    0      89     170               31
#
#    Absenteeism time in hours
# 0                          4
# 1                          0
# ...

# %%
#8
df.tail(4)
# Out:
#      ID  Seasons  Transportation expense  Distance from Residence to Work  \
# 736   1        1                     235                               11
# 737   4        1                     118                               14
# 738   8        2                     231                               35
# 739  35        3                     179                               45
#
#      Service time  Age  Work load Average/day   Hit target  Education  Son  \
# 736            14   37                 264.604          93          3    1
# 737            13   40                 271.219          95          1    1
# 738            14   39                 271.219          95          1    2
# 739            14   53                 271.219          95          1    1
#
#      Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 736               0              0    1      88     172               29
# ...

# %%
#9
print("First row corresponding to roll no 201 :")
df.iloc[201]
# Out:
# First row corresponding to roll no 201 :
# ID                                  11.000
# Seasons                              3.000
# Transportation expense             289.000
# Distance from Residence to Work     36.000
# Service time                        13.000
# Age                                 33.000
# Work load Average/day              326.452
# Hit target                          96.000
# Education                            1.000
# Son                                  2.000
# Social drinker                       1.000
# Social smoker                        0.000
# Pet                                  1.000
# Weight                              90.000
# Height                             172.000
# Body mass index                     30.000
# Absenteeism time in hours           16.000
# Name: 201, dtype: float64

# %%
#10
rows=df.shape[0]
print("Number of rows = ",rows)
# Out:
# Number of rows =  740

# %%
#11
df.iloc[0:2,0:5]
# Out:
#    ID  Seasons  Transportation expense  Distance from Residence to Work  \
# 0  11        1                     289                               36
# 1  36        1                     118                               13
#
#    Service time
# 0            13
# 1            18

# %%
#12
#IX Diseases of the circulatory system
df4=df.loc[df['Reason for absence']==9]
res=df4.shape[0]
print(res)
df4
# Out:
# 4
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 274  24                   9                 9                2        1
# 279  24                   9                 9                4        1
# 471  28                   9                 7                3        1
# 536  34                   9                11                3        4
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 274                     246                               25            16
# 279                     246                               25            16
# 471                     225                               26             9
# 536                     118                               10            10
#
#      Age  Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 274   41                 294.217  ...                     0          1    0
# ...

# %%
df.rename(columns={'Body mass index':'BMI'},inplace=True)
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
#13
df3=df.groupby('BMI').mean()
print("Overweight")
df1=df.loc[(df['BMI']>=25) & (df['BMI']<=30)]
df1.groupby('BMI').mean()
# Out:
# Overweight
#             ID   Seasons  Transportation expense  \
# BMI
# 25   15.888889  2.698413              259.190476
# 27   10.000000  2.583333              361.000000
# 28   33.661017  2.525424              125.254237
# 29    1.000000  2.478261              235.000000
# 30   11.000000  2.200000              289.000000
#
#      Distance from Residence to Work  Service time        Age  \
# BMI
# 25                         20.920635     11.341270  35.095238
# 27                         52.000000      3.000000  28.000000
# 28                         10.338983     10.338983  37.271186
# 29                         11.000000     14.000000  37.000000
# 30                         36.000000     13.000000  33.000000
#
#      Work load Average/day   Hit target  Education       Son  Social drinker  \
# BMI
# 25               275.927984   94.428571   1.309524  1.357143        0.698413
# 27               258.870250   94.125000   1.000000  1.000000        1.000000
# ...

# %%
print("Obese")
df2=df.loc[df['BMI']>=30]
df2.groupby('BMI').mean()
# Out:
# Obese
#             ID   Seasons  Transportation expense  \
# BMI
# 30   11.000000  2.200000              289.000000
# 31   10.632653  2.489796              164.891156
# 32   33.000000  2.708333              248.000000
# 33    2.000000  1.666667              235.000000
# 34    4.000000  1.000000              118.000000
# 35    8.000000  1.500000              231.000000
# 36   32.000000  3.000000              289.000000
# 38    5.000000  2.842105              235.000000
#
#      Distance from Residence to Work  Service time       Age  \
# BMI
# 30                         36.000000          13.0  33.00000
# 31                         42.210884          18.0  40.77551
# 32                         25.000000          14.0  47.00000
# 33                         29.000000          12.0  48.00000
# 34                         14.000000          13.0  40.00000
# 35                         35.000000          14.0  39.00000
# 36                         48.000000          29.0  49.00000
# ...

# %%
#14
# highschoolers=1
# graduates=2
# postgraduates=3 
# master and doctor=4
df.groupby(['Education','Age']).mean()
# Out:
#                       ID   Seasons  Transportation expense  \
# Education Age
# 1         27   27.000000  1.857143              184.000000
#           28   23.732673  2.861386              257.316832
#           29   30.000000  1.857143              157.000000
#           31   13.000000  3.400000              369.000000
#           32   19.000000  1.333333              291.000000
#           33   10.166667  2.229167              272.333333
#           34   14.000000  2.448276              155.000000
#           36   20.480000  2.580000              278.880000
#           37   34.000000  2.509091              118.000000
#           38    3.000000  2.371681              179.000000
#           39    7.250000  2.125000              267.000000
#           40   14.710526  2.973684              286.447368
#           41   24.000000  2.233333              246.000000
#           43    9.375000  2.625000              248.541667
#           46   16.000000  3.000000              118.000000
# ...

# %%
df.groupby(['Education','Age']).std()
# Out:
#                      ID  Reason for absence  Month of absence  \
# Education Age
# 1         27   0.000000            8.056349          3.366502
#           28   7.705701            6.685288          3.831500
#           29   0.000000           10.179344          3.579040
#           31   0.000000            9.119837          2.992053
#           32   0.000000           14.106736          3.214550
#           33   1.883109            6.305709          3.299944
#           34   0.000000            7.542164          3.261207
#           36   1.110984           10.322237          3.162020
#           37   0.000000            7.502502          3.832960
#           38   0.000000            6.642570          3.555191
#           39   0.462910            8.860023          3.583195
#           40   1.784436            8.945743          3.180667
#           41   0.000000            9.265931          3.147887
#           43   8.711873           10.288237          2.710353
# ...

# %%
#15
res1=df['Transportation expense'].mean()
print("Average Transportation Expense :",res1)
# Out:
# Average Transportation Expense : 221.32972972972973

# %%
res2=df['Transportation expense'].var()
print("Variance Transportation Expense :",res2)
# Out:
# Variance Transportation Expense : 4482.600197491131

# %%
#16
socdrink=df.loc[df['Social drinker']==1]
socdrink
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 732  10                  22                 7                4        1
# 734  13                  13                 7                2        1
# 735  11                  14                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
hist=socdrink.Age.hist()
hist.set_xlabel('Age of Social Drinkers')
hist.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
print("Skewness : ")
skewness=socdrink.skew()
print(skewness[8])
print("Skewness of Age is Positive")
# Out:
# Skewness :
# 0.5083426436631391
# Skewness of Age is Positive

# %%
print("Skew of the Distribution")
skewness
# Out:
# Skew of the Distribution
# ID                                 0.798508
# Reason for absence                -0.983478
# Month of absence                  -0.000891
# Day of the week                    0.063402
# Seasons                           -0.004931
# Transportation expense             0.244564
# Distance from Residence to Work   -0.325769
# Service time                      -1.138402
# Age                                0.508343
# Work load Average/day              1.064777
# Hit target                        -1.371020
# Disciplinary failure               3.565811
# Education                          8.213357
# Son                                0.918766
# Social drinker                     0.000000
# Social smoker                      4.263772
# Pet                                3.437350
# Weight                            -0.143375
# Height                             2.340644
# Body mass index                    0.374925
# Absenteeism time in hours          5.104189
# ...
