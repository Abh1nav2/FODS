# %%
import matplotlib as mpl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('classic') 
# %matplotlib inline
x=[0,30,45,60,90]
y=[10,20,30,40,50]

# %%
se=pd.Series(x,index=y)
se
# Out:
# 10     0
# 20    30
# 30    45
# 40    60
# 50    90
# dtype: int64

# %%
plt.subplot(4,1,1)
plt.plot(x,y)
plt.subplot(4,1,2)
plt.plot(y) 
plt.subplot(4,1,3)
plt.plot(np.sin(x))
plt.subplot(4,1,4)
plt.plot(np.cos(x))

# %%
df=pd.read_csv('https://raw.githubusercontent.com/reisanar/datasets/master/BostonHousing.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO  LSTAT  MEDV  CAT_MEDV
# 0       15.3   4.98  24.0         0
# 1       17.8   9.14  21.6         0
# ...

# %%
df=df.rename(columns={'CRIM':'CRI MSON','ZN':'NOZN'})
df.head()  
df.describe()
# Out:
#          CRI MSON        NOZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
df.plot.scatter(x='CRIM SON',y='NOZN')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CRIMSON'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
s=df.groupby("CHAS").mean()
s
# Out:
#           CRIM         ZN      INDUS       NOX        RM        AGE       DIS  \
# CHAS
# 0     3.744447  11.634820  11.019193  0.551817  6.267174  67.911677  3.851915
# 1     1.851670   7.714286  12.719143  0.593426  6.519600  77.500000  3.029709
#
#            RAD         TAX    PTRATIO      LSTAT       MEDV  CAT_MEDV
# CHAS
# 0     9.566879  409.870488  18.527176  12.757941  22.093843  0.154989
# 1     9.314286  386.257143  17.491429  11.241714  28.440000  0.314286

# %%
bar=df.groupby("CHAS").mean().MEDV.plot(kind='bar')
bar.set_ylabel('average')
bar.set_xlabel('x axis')
# Out:
# Text(0.5, 0, 'x axis')

# %%
hist=df.MEDV.hist()
hist.set_xlabel('medv')
hist.set_ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
boxplot=df.boxplot(column='MEDV',by="CHAS")
boxplot.set_xlabel('chas')
boxplot.set_ylabel('medv')
plt.title("")
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# Text(0.5, 1.0, '')

# %%
fig,axes=plt.subplots(1,4)
df.boxplot(column="AGE",by="CAT_MEDV",ax=axes[0])
df.boxplot(column="TAX",by="CAT_MEDV",ax=axes[1])
df.boxplot(column="ZN",by="CAT_MEDV",ax=axes[2])
df.boxplot(column="RAD",by="CAT_MEDV",ax=axes[3])
plt.suptitle("")
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# ...

# %%
df.corr().round(2)
# Out:
#           CRIM    ZN  INDUS  CHAS   NOX    RM   AGE   DIS   RAD   TAX  \
# CRIM      1.00 -0.20   0.41 -0.06  0.42 -0.22  0.35 -0.38  0.63  0.58
# ZN       -0.20  1.00  -0.53 -0.04 -0.52  0.31 -0.57  0.66 -0.31 -0.31
# INDUS     0.41 -0.53   1.00  0.06  0.76 -0.39  0.64 -0.71  0.60  0.72
# CHAS     -0.06 -0.04   0.06  1.00  0.09  0.09  0.09 -0.10 -0.01 -0.04
# NOX       0.42 -0.52   0.76  0.09  1.00 -0.30  0.73 -0.77  0.61  0.67
# RM       -0.22  0.31  -0.39  0.09 -0.30  1.00 -0.24  0.21 -0.21 -0.29
# AGE       0.35 -0.57   0.64  0.09  0.73 -0.24  1.00 -0.75  0.46  0.51
# DIS      -0.38  0.66  -0.71 -0.10 -0.77  0.21 -0.75  1.00 -0.49 -0.53
# RAD       0.63 -0.31   0.60 -0.01  0.61 -0.21  0.46 -0.49  1.00  0.91
# TAX       0.58 -0.31   0.72 -0.04  0.67 -0.29  0.51 -0.53  0.91  1.00
# PTRATIO   0.29 -0.39   0.38 -0.12  0.19 -0.36  0.26 -0.23  0.46  0.46
# LSTAT     0.46 -0.41   0.60 -0.05  0.59 -0.61  0.60 -0.50  0.49  0.54
# ...

# %%
x=[10,20,30,40,50,60,70]
y=[60,70,80,90,100,120,150]
dfs=pd.Series(y,index=x)
line=dfs.plot(ylim=[50,200],legend=True,label="sbsxslxsc")
line.set_ylabel("hello")
# Out:
# Text(0, 0.5, 'hello')

# %%
tdf=pd.read_csv('/content/drive/MyDrive/Data Science/test1.csv.xls')
tdf.columns=['Srl No', 'age', 'type_employer', 'fnlwgt','education', 'education_num', 'marital','occupation','relationship', 'race','sex', 'capital_gain', 'capital_loss','hr_per_week', 'country', 'income']
tdf
# Out:
#        Srl No  age      type_employer  fnlwgt    education  education_num  \
# 0           0   50   Self-emp-not-inc   83311    Bachelors             13
# 1           1   38            Private  215646      HS-grad              9
# 2           2   53            Private  234721         11th              7
# 3           3   28            Private  338409    Bachelors             13
# 4           4   37            Private  284582      Masters             14
# ...       ...  ...                ...     ...          ...            ...
# 32555   32555   27            Private  257302   Assoc-acdm             12
# 32556   32556   40            Private  154374      HS-grad              9
# 32557   32557   58            Private  151910      HS-grad              9
# 32558   32558   22            Private  201490      HS-grad              9
# 32559   32559   52       Self-emp-inc  287927      HS-grad              9
#
#                    marital          occupation    relationship    race  \
# ...

# %%
tdf.iloc[:,1:2]
# Out:
#        age
# 0       50
# 1       38
# 2       53
# 3       28
# 4       37
# ...    ...
# 32555   27
# 32556   40
# 32557   58
# 32558   22
# 32559   52
#
# [32560 rows x 1 columns]

# %%
ans=tdf.groupby('country').count()
ans.rename(columns={'Srl No':"ssss"},inplace=True)
ans
# Out:
#                               ssss    age  type_employer  fnlwgt  education  \
# country
#  ?                             583    583            583     583        583
#  Cambodia                       19     19             19      19         19
#  Canada                        121    121            121     121        121
#  China                          75     75             75      75         75
#  Columbia                       59     59             59      59         59
#  Cuba                           95     95             95      95         95
#  Dominican-Republic             70     70             70      70         70
#  Ecuador                        28     28             28      28         28
#  El-Salvador                   106    106            106     106        106
#  England                        90     90             90      90         90
#  France                         29     29             29      29         29
# ...

# %%
gdf=tdf.groupby('sex').count()
x=gdf.iloc[1,:1]

# %%
res1=tdf.groupby(['income','sex']).count()
res1
# Out:
#                 Srl No    age  type_employer  fnlwgt  education  \
# income sex
#  <=50K  Female    9592   9592           9592    9592       9592
#         Male     15127  15127          15127   15127      15127
#  >50K   Female    1179   1179           1179    1179       1179
#         Male      6662   6662           6662    6662       6662
#
#                 education_num  marital  occupation  relationship   race  \
# income sex
#  <=50K  Female           9592     9592        9592          9592   9592
#         Male            15127    15127       15127         15127  15127
#  >50K   Female           1179     1179        1179          1179   1179
#         Male             6662     6662        6662          6662   6662
#
#                 capital_gain  capital_loss  hr_per_week  country
# income sex
#  <=50K  Female          9592          9592         9592     9592
#         Male           15127         15127        15127    15127
# ...

# %%
count=res1.iloc[3,2]
print(count)

total=res1['Srl No'].sum()
print(total)
# Out:
# 6662
# 32560

# %%
ams=tdf.kurt()
reslt=ams.iloc[1]
reslt
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# -0.166212226734332

# %%
resl=tdf.skew()
resl.iloc[1]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# 0.5587376395152729

# %%
tdf.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Srl No            16279.500000
# age                  38.581634
# fnlwgt           189781.814373
# education_num        10.080590
# capital_gain       1077.615172
# capital_loss         87.306511
# hr_per_week          40.437469
# dtype: float64

# %%
tdf.var()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Srl No           8.834885e+07
# age              1.860671e+02
# fnlwgt           1.114075e+10
# education_num    6.618831e+00
# capital_gain     5.454418e+07
# capital_loss     1.623817e+05
# hr_per_week      1.524637e+02
# dtype: float64

# %%
tdf.std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Srl No             9399.406719
# age                  13.640642
# fnlwgt           105549.764924
# education_num         2.572709
# capital_gain       7385.402999
# capital_loss        402.966116
# hr_per_week          12.347618
# dtype: float64

# %%
res2=tdf.groupby('sex').mean()
res2
# Out:
#                Srl No        age         fnlwgt  education_num  capital_gain  \
# sex
#  Female  16312.043636  36.858230  185746.311206      10.035744    568.410547
#  Male    16263.412639  39.433567  191776.692735      10.102758   1329.331314
#
#          capital_loss  hr_per_week
# sex
#  Female     61.187633    36.410361
#  Male      100.217908    42.428198

# %%
box=tdf.boxplot(column='age',by='income')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
x=[10,20,30,20,50,45,70]
y=[45,78,95,36,15,20,57]
data={'x':x,'y':y}
data=pd.DataFrame(data)

# %%
c=data.x.nunique()
y=data.shape
print(y[0])
print((c/y[0])*100)
# Out:
# 7
# 85.71428571428571

# %%
import seaborn as sb
sb.histplot(tdf['age'],stat='probability',bins=20)

# %%
data.plot.scatter(x='x',y='y')

# %%
data.y.plot(kind='bar')

# %%
data.x.hist()

# %%
import seaborn as sb
sb.histplot(tdf['age'],stat='probability',bins=20)

# %%
data.drop(columns=['new'],inplace=True)
data.columns=['newx','newy']
data
# Out:
#    newx  newy
# 0    10    45
# 1    20    78
# 2    30    95
# 3    20    36
# 4    50    15
# 5    45    20
# 6    70    57

# %%
data.loc[data['newx']>30].count()
# Out:
# newx    3
# y       3
# dtype: int64

# %%
data.loc[(data['newx']==20) & (data['newy']==36)]
# Out:
#    newx  newy
# 3    20    36

# %%
data.rename(columns={'newy':'y'},inplace=True)
data
# Out:
#    newx   y
# 0    10  45
# 1    20  78
# 2    30  95
# 3    20  36
# 4    50  15
# 5    45  20
# 6    70  57

# %%
data.where(data['newx']==20)
# Out:
#    newx     y
# 0   NaN   NaN
# 1  20.0  78.0
# 2   NaN   NaN
# 3  20.0  36.0
# 4   NaN   NaN
# 5   NaN   NaN
# 6   NaN   NaN

# %%
scat=data.plot.scatter(x='x',y='y')
scat.set_xlabel('x axis')
scat.set_ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
bar=data.x.plot(kind="bar")
bar.set_xlabel('X axis')
# Out:
# Text(0.5, 0, 'X axis')

# %%
hist=data.x.hist()

# %%
data.loc[data['x']==50,'x']=99
data
# Out:
#     x   y
# 0  10  45
# 1  20  78
# 2  30  95
# 3  20  36
# 4  99  15
# 5  45  20
# 6  70  57

# %%
box=data.boxplot(column='x',by='y'])
box
